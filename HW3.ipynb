# %% [markdown]
# <a href="https://colab.research.google.com/github/EvgenEgorov/transcriptomics_msu_HW/blob/main/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Семинар 3. Определение максимально правдоподобных распределений для данных
#
# Для того, чтобы корректно применять статистические тесты, а также выуживать из данных максимальное количество информации, которая в них хранится, необходимо точно понимать, по какому закону эти данные распределены.
#
# На этом семинаре мы разберём, как корректно понять, что именно за распределение в данных мы наблюдаем. Для примера мы загрузим набор данных из ресурса <a href="https://jhubiostatistics.shinyapps.io">ReCount2</a> (в целом это полезный ресурс в случае, если вам необходимо загрузить из открытых источников именно RNA-Seq count data).

# %%
# Загрузка R magic
# !pip install rpy2==3.5.1
# %load_ext rpy2.ipython

# Установка нужных пакетов
# !Rscript -e 'install.packages("fitdistrplus", repos="https://cloud.r-project.org")'

# Загрузка датасета
# !gdown --id 1nlpCcK6LoqEJnvCqEdcUFNElZSoz_3Kg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: rpy2==3.5.1 in /usr/local/lib/python3.8/dist-packages (3.5.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from rpy2==3.5.1) (2022.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from rpy2==3.5.1) (2.11.3)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.8/dist-packages (from rpy2==3.5.1) (1.5.1)
# Requirement already satisfied: cffi>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from rpy2==3.5.1) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.10.0->rpy2==3.5.1) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->rpy2==3.5.1) (2.0.1)
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# trying URL 'https://cloud.r-project.org/src/contrib/fitdistrplus_1.1-8.tar.gz'
# Content type 'application/x-gzip' length 2434918 bytes (2.3 MB)
# ==================================================
# downloaded 2.3 MB
#
# * installing *source* package ‘fitdistrplus’ ...
# ** package ‘fitdistrplus’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** data
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (fitdistrplus)
#
# The downloaded source packages are in
# 	‘/tmp/RtmpeF6wsr/downloaded_packages’
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1nlpCcK6LoqEJnvCqEdcUFNElZSoz_3Kg
# To: /content/LUAD_counts.tsv
# 100% 3.18M/3.18M [00:00<00:00, 116MB/s]

# %%
# !gdown --id 1nlpCcK6LoqEJnvCqEdcUFNElZSoz_3Kg
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1nlpCcK6LoqEJnvCqEdcUFNElZSoz_3Kg
# To: /content/LUAD_counts.tsv
# 100% 3.18M/3.18M [00:00<00:00, 197MB/s]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Настройка отображения
plt.rcParams["figure.dpi"] = 100

# %%
# Прочтение датасета
df = pd.read_csv("LUAD_counts.tsv", sep="\t")
df.index = [gene.split(".")[0] for gene in df.gene_name]
del df["gene_name"]
df = df.T

# %% [markdown]
# Первое, что необходимо сделать, &mdash; это посмотреть на распределение данных глазами, построив гистограмму.

# %%
gene = "MT-CO1"
expr = np.array(df[gene])
sns.histplot(expr, bins=20)

# %% [markdown]
# В принципе похоже на нормальное распределение, не так ли? Легко можно представить, как именно на таких данных запускают классический t-test. Однако давайте оценим его нормальность при помощи классического теста, который проходят в университете.

# %%
from scipy.stats import shapiro

stat, p = shapiro(df[gene])
print(f"Statistics={stat:3f}, p={p:3f}")
# Out:
# Statistics=0.742976, p=0.000001

# %% [markdown]
# Уже не выглядит так, что данные нормальные, да? Как вообще понимают, какое распределение описывает данные лучше всего? Для начала разберёмся, как оценивают, хорошо ли описываются данные каким-то распределением. При помощи пакета <code>fitdistrplus</code> для R попробуем описать наши данные нормальным распределением и разберём, что конкретно происходило.

# %% [markdown]
# ## Зависимость дисперсии от среднего

# %%
means = np.mean(df.values, axis=0)
vars = np.var(df.values, axis=0)

means = means[vars > 0]
vars = vars[vars > 0]

means = np.log10(means)
vars = np.log10(vars)

# %%
sns.set_style("ticks")
fig, ax = plt.subplots(figsize=(4, 4), dpi=100)

ax.scatter(means, vars)
ax.plot([-3, 12], [-3, 12], color="red")
ax.set_xlim(-3, 12)
ax.set_ylim(-3, 12)
ax.grid(alpha=0.3)

ax.set_xlabel("log$_{10}$(Mean)")
ax.set_ylabel("log$_{10}$(Variance)")
# Out:
# Text(0, 0.5, 'log$_{10}$(Variance)')

# %% [markdown]
# ## Тестирование конкретного распределения
#
# Допустим, мы знаем, что наш набор данных описывается нормальным распределением (или каким-либо иным параметрическим распределением). Но как определить, какие именно параметры такого распределения? Мы можем найти максимально правдоподобную оценку такого распределения.

# %%
# %%R
# library(fitdistrplus)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: MASS
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Loading required package: survival

# %%
# %%R
# data <- as.vector(expr)
# fit.norm <- fitdist(data, "norm")
# summary(fit.norm)
# Out:
# Fitting of the distribution ' norm ' by maximum likelihood
# Parameters :
#      estimate Std. Error
# mean 553010.3          0
# sd   464404.5          0
# Loglikelihood:  -578.698   AIC:  1161.396   BIC:  1164.774
# Correlation matrix:
#      mean  sd
# mean    1 NaN
# sd    NaN   1

# %% [markdown]
# Нарисуем графики для анализа:

# %%
# %%R -r 100 -w 800 -h 600
# plot(fit.norm)

# %% [markdown]
# Пока будем ориентироваться только на правдоподобие того, что данные порождены этим распределением. Как вы думаете, у нас высокое или низкое значение правдоподобия?

# %% [markdown]
# ### Задание
#
# Сравните несколько распределений и определите, какое из них, по вашему мнению, лучше всего описывает данные. Для того, чтобы найти доступные для использования распределения, прочитайте документацию пакета по <a href="https://cran.r-project.org/web/packages/fitdistrplus/fitdistrplus.pdf">ссылке</a>.

# %%
#Попробуем логнормальное распределение, распределение Пуассона (просто так) и экспоненциальное 

# %%R
fit.lnorm <- fitdist(data, "lnorm")
fit.pois <- fitdist(data,"pois")
fit.nbinom <- fitdist(data,"nbinom")

fit.lnorm$aic
# Out:
# [1] 1130.279

# %%
# %%R -r 100 -w 800 -h 600
# plot(fit.lnorm)

# %%
#Распределение Пуассона показывает какой-то ужас
# %%R -r 100 -w 800 -h 600
plot(fit.pois)

# %%
#Негативное биномиальное распределение тоже показывает какой-то ужас, хотя, может быть, я что-то напутал с параметрами
# %%R -r 100 -w 800 -h 600
plot(fit.nbinom)

# %% [markdown]
# Выглядит так, будто данные лучше всего описываются логнормальным распределением, там все графики наиболее пристойно выглядят (QQ-plot вообще отличный)

# %% [markdown]
# ## Сравнение тестов между собой
#
# После того, как мы нашли Likelihood того, что наши данные порождены определённым распределением с определёнными параметрами, нам необходимо сравнить модели между собой, чтобы понять, какая из них описывает данные лучше. Казалось бы, можно сравнить правдоподобия и всё, однако у распределений есть ещё один важный параметр, который мы не учли, &mdash; это число параметров самой модели.
#
# Для того, чтобы учитывать число параметров самой модели, существует информационный критерий Акаике
# $\mathrm{AIC} = 2k – 2(\mathrm{LogLikelihood})$, где $k$ &mdash; это число параметров модели. И то распределение, которое будет иметь меньшее значение AIC, и будет более предпочтительным.
#
# Посмотрим заново на результаты того, как мы зафитили нашу модель:

# %%
# %%R
# summary(fit.norm)
# Out:
# Fitting of the distribution ' norm ' by maximum likelihood
# Parameters :
#      estimate Std. Error
# mean 553010.3          0
# sd   464404.5          0
# Loglikelihood:  -578.698   AIC:  1161.396   BIC:  1164.774
# Correlation matrix:
#      mean  sd
# mean    1 NaN
# sd    NaN   1

# %% [markdown]
# Так же мы можем сравнить CDF нашего распределения и тех распределений, которые мы зафитили:

# %%
# %%R -r 100
# fit_n  <- fitdist(data, "norm")
# fit_p  <- fitdist(data, "pois")
# fit_nb  <- fitdist(data, "nbinom")
# fit_ln  <- fitdist(data, "lnorm")
# cdfcomp(list(fit_n, fit_p, fit_ln, fit_nb), legendtext = c("Normal", "Poisson", "Log Normal", "Negative Binomial"))

# %%
# %%R
# summary(fit_nb)
# fit_nb
# Out:
# NULL

# %%
# %%R
# summary(fit_n)
# Out:
# Fitting of the distribution ' norm ' by maximum likelihood
# Parameters :
#      estimate Std. Error
# mean 553010.3          0
# sd   464404.5          0
# Loglikelihood:  -578.698   AIC:  1161.396   BIC:  1164.774
# Correlation matrix:
#      mean  sd
# mean    1 NaN
# sd    NaN   1

# %% [markdown]
# Также для того, чтобы оценить нестабильность наших данных, можно использовать бутстрэп.

# %%
# %%R -r 100
# fit_ln.boot <- bootdist(fit_ln, "param")
# CIcdfplot(fit_ln.boot, CI.output = "probability")

# %% [markdown]
# Или использовать оценки третьего и четвёртого моментов для того, чтобы хотя бы приблизительно понять, к какому распределению наши данные могут быть отнесены:

# %%
# %%R -r 100 -w 600 -h 600
# descdist(data, discrete=TRUE, boot=500)
# Out:
# summary statistics
# ------
# min:  62918   max:  2682832
# median:  396275.5
# mean:  553010.3
# estimated sd:  470320.8
# estimated skewness:  2.709948
# estimated kurtosis:  13.21073

# %% [markdown]
# ## Домашнее задание
#
# Определите максимально правдоподобное распределение для наших даных. Попробуйте это сделать на случайной выборке из экспрессий 30 других генов. Согласованный ли получился результат?

# %%
# %%R
# library(fitdistrplus)
# library(tidyverse)
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ✖ dplyr::select() masks MASS::select()

# %%
import random 
thirty_genes = random.choices(list(df.columns),k=30)
df_selected = df[thirty_genes]

# %%
import rpy2.robjects as ro
#Проверим распределение Пуассона, нормальное, логнормальное и негативное биномиальное
aic_lnorm,aic_nbinom,aic_pois,aic_norm = [],[],[],[]
for gene in thirty_genes:
  ro.globalenv['chosen_gene'] = list(df[gene])
  aic_norm.append(ro.r('fitdist(unlist(chosen_gene),"norm")$aic'))
  aic_pois.append(ro.r('lnorm_aic <- fitdist(unlist(chosen_gene),"pois")$aic'))
  aic_nbinom.append(ro.r('lnorm_aic <- fitdist(unlist(chosen_gene),"nbinom")$aic'))

# %%
# %%R -i df_selected
# df_norm <- sapply(df_selected,function(x) fitdist(x,"norm")$aic)
# df_pois <- sapply(df_selected,function(x) fitdist(x,"pois")$aic)
# df_nbinom <- sapply(df_selected,function(x) fitdist(x,"nbinom")$aic)

# %%
# %%R -i df_selected
# df <- data.frame(genes = colnames(df_selected),
#                  norm = c(sapply(df_selected,function(x) fitdist(x,"norm")$aic)),
#                  pois = sapply(df_selected,function(x) fitdist(x,"pois")$aic),
#                  nbinom = sapply(df_selected,function(x) fitdist(x,"nbinom")$aic))
# df %>%
# pivot_longer(!genes,names_to = "distribution",values_to = "aic") %>%
# ggplot()+
# geom_boxplot(aes(x = distribution,y=aic,fill = distribution))+
# theme_bw()+
# theme(legend.position = "none",
#       axis.text.x = element_text(size=18,color='black'),
#       axis.text.y = element_text(size=18,color='black'))

# %% [markdown]
# Видим, что AIC в распределении Пуассона настолько огромный, что мы не можем разглядеть показатели негативного биномиального и нормального распределений. Это говорит нам о неприменимости распределения Пуассона к нашим данным.
# Попробуем убрать Пуассона и посмотреть, как ведут себя nbinom и norm распределения.

# %%
# %%R
# df %>%
# select(!pois) %>%
# pivot_longer(!genes,names_to = "distribution",values_to = "aic") %>%
# ggplot()+
# geom_boxplot(aes(x = distribution,y=aic,fill = distribution))+
# theme_bw()+
# theme(legend.position = "none",
#       axis.text.x = element_text(size=18,color='black'),
#       axis.text.y = element_text(size=18,color='black'))

# %% [markdown]
# Видим, что в среднем чуть лучше описывает наши данные негативное биномиальное распределение

# %% [markdown]
# # Задание 2
# *Скачайте датасет <code>1M8-86VecaYPERovPk4JKhT2lLa4PfJxi</code> из статьи <a href="https://bmcgenomics.biomedcentral.com/articles/10.1186/1471-2164-13-304#Sec8">Oberg et al., 2012</a>. Внимательно прочитайте статью и изучите дизайн эксперимента &mdash; какие реплики в статье называют техническими, а какие &mdash; биологическими? Правда ли в технических репликах наблюдается распределение Пуассона?*

# %%
# !gdown 1M8-86VecaYPERovPk4JKhT2lLa4PfJxi
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1M8-86VecaYPERovPk4JKhT2lLa4PfJxi
# To: /content/GSE29022_gene_counts.txt
# 100% 2.76M/2.76M [00:00<00:00, 39.6MB/s]

# %%
df_hw = pd.read_csv("GSE29022_gene_counts.txt",sep="\t")
df_hw = df_hw.T

# %% [markdown]
# В данном эксперименте биологические реплики представляют собой образцы, полученные от различных пациентов. Технические же реплики представляют собой один и тот же образец, нанесённый в разные лунки секвенатора (lanes, не помню, как это правильно переводится).

# %%
means = np.mean(df_hw.values, axis=0)
vars = np.var(df_hw.values, axis=0)

means = means[vars > 0]
vars = vars[vars > 0]

means = np.log10(means)
vars = np.log10(vars)
sns.set_style("ticks")
fig, ax = plt.subplots(figsize=(4, 4), dpi=100)

ax.scatter(means, vars)
ax.plot([-3, 6], [-3, 6], color="red")
ax.grid(alpha=0.3)

ax.set_xlabel("log$_{10}$(Mean)")
ax.set_ylabel("log$_{10}$(Variance)")
# Out:
# Text(0, 0.5, 'log$_{10}$(Variance)')

# %% [markdown]
# Кажется, что распределение Пуассона не наблюдается в технических репликах - слишком уж отходит от линии y=x

# %% [markdown]
# # Задание 3
# *Проделайте подобную процедуру с каунтами генов, которые вы получили в результате анализа <a href="https://www.nature.com/articles/s41598-018-23226-4">статьи</a> со сравнением методов подготовки библиотек для scRNA-Seq (`1Mh2T7YyWG9LPQsuNGy_IdYhbbzUgZUek`). Разберитесь, что в случае этой работы называют технической репликой. Актуально ли распределение Пуассона в случае таких технических реплик?*

# %% [markdown]
# **Ответ**
#
# В данной статье техническими репликами называют образцы одной ткани, отсеквенированые с использованием различных методов подготовки библиотек (polyA selection или rRNA depletion).
# Посмотрим на график зависимости log10variance от log10mean.

# %%
# !gdown 1Mh2T7YyWG9LPQsuNGy_IdYhbbzUgZUek
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Mh2T7YyWG9LPQsuNGy_IdYhbbzUgZUek
# To: /content/polyA_total_counts.tsv
# 100% 1.87M/1.87M [00:00<00:00, 151MB/s]

# %%
df_hw_2 = pd.read_csv("polyA_total_counts.tsv",sep="\t", index_col = 0)
df_hw_2 = df_hw_2.T

# %%
means = np.mean(df_hw_2.values, axis=0)
vars = np.var(df_hw_2.values, axis=0)

means = means[vars > 0]
vars = vars[vars > 0]

means = np.log10(means)
vars = np.log10(vars)
sns.set_style("ticks")
fig, ax = plt.subplots(figsize=(4, 4), dpi=100)

ax.scatter(means, vars)
ax.plot([-3, 6], [-3, 6], color="red")
ax.grid(alpha=0.3)

ax.set_xlabel("log$_{10}$(Mean)")
ax.set_ylabel("log$_{10}$(Variance)")
# Out:
# Text(0, 0.5, 'log$_{10}$(Variance)')

# %% [markdown]
# Здесь, кажется, тоже не наблюдается Пуассоновского распределения.
